# %%
from statsbombpy import sb
import pandas as pd

# %%
competitions = sb.competitions()
matches = sb.matches(competition_id=43, season_id=106)
# Out:
# c:\cosmos\.venv\Lib\site-packages\statsbombpy\api_client.py:23: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
events = sb.events(match_id= 3857279)
events.head()
# Out:
# c:\cosmos\.venv\Lib\site-packages\statsbombpy\api_client.py:23: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#   50_50 ball_receipt_outcome ball_recovery_recovery_failure block_deflection  \
# 0   NaN                  NaN                            NaN              NaN
# 1   NaN                  NaN                            NaN              NaN
# 2   NaN                  NaN                            NaN              NaN
# 3   NaN                  NaN                            NaN              NaN
# 4   NaN                  NaN                            NaN              NaN
#
#   block_save_block carry_end_location clearance_aerial_won  \
# 0              NaN                NaN                  NaN
# 1              NaN                NaN                  NaN
# 2              NaN                NaN                  NaN
# 3              NaN                NaN                  NaN
# 4              NaN                NaN                  NaN
#
#   clearance_body_part clearance_head clearance_left_foot  ...  \
# 0                 NaN            NaN                 NaN  ...
# 1                 NaN            NaN                 NaN  ...
# 2                 NaN            NaN                 NaN  ...
# 3                 NaN            NaN                 NaN  ...
# 4                 NaN            NaN                 NaN  ...
#
#   substitution_outcome substitution_outcome_id substitution_replacement  \
# 0                  NaN                     NaN                      NaN
# 1                  NaN                     NaN                      NaN
# 2                  NaN                     NaN                      NaN
# 3                  NaN                     NaN                      NaN
# 4                  NaN                     NaN                      NaN
#
#   substitution_replacement_id  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
#                                              tactics       team team_id  \
# 0  {'formation': 4231, 'lineup': [{'player': {'id...     France     771
# 1  {'formation': 4141, 'lineup': [{'player': {'id...  Australia     792
# 2                                                NaN     France     771
# 3                                                NaN  Australia     792
# 4                                                NaN     France     771
#
#       timestamp         type under_pressure
# 0  00:00:00.000  Starting XI            NaN
# 1  00:00:00.000  Starting XI            NaN
# 2  00:00:00.000   Half Start            NaN
# 3  00:00:00.000   Half Start            NaN
# 4  00:00:00.000   Half Start            NaN
#
# [5 rows x 92 columns]

# %%
matches.head()
# Out:
#    match_id  match_date      kick_off  home_score  away_score match_status  \
# 0   3857276  2022-12-01  15:00:00.000           1           2    available
# 1   3857271  2022-11-21  13:00:00.000           6           2    available
# 2   3857296  2022-12-01  15:00:00.000           0           0    available
# 3   3857274  2022-11-25  16:00:00.000           1           1    available
# 4   3857255  2022-12-01  19:00:00.000           2           1    available
#
#   match_status_360                last_updated            last_updated_360  \
# 0        available  2026-05-04T01:46:04.664252  2026-05-04T01:50:33.318123
# 1        available  2026-05-04T01:40:47.671394  2026-05-04T01:43:30.216315
# 2        available  2026-05-04T01:44:02.255386  2026-05-04T01:50:06.343225
# 3        available  2026-05-04T01:43:00.444702  2026-05-04T01:50:07.646458
# 4        available  2026-05-04T01:42:55.630428  2026-05-04T01:49:36.594944
#
#    match_week  ...  home_manager_country_name away_manager_id  \
# 0           3  ...                    England         1000518
# 1           1  ...                    England             645
# 2           3  ...                    Croatia             263
# 3           2  ...                Netherlands            2881
# 4           3  ...                      Japan             793
#
#                   away_manager_name away_manager_nickname  away_manager_dob  \
# 0                    Walid Regragui                   NaN        1975-09-23
# 1  Carlos Manuel Brito Leal Queiróz        Carlos Queiroz        1953-03-01
# 2         Roberto Martínez Montoliú      Roberto Martínez        1973-07-13
# 3              Gustavo Julio Alfaro        Gustavo Alfaro        1962-08-14
# 4      Luis Enrique Martínez García          Luis Enrique        1970-05-08
#
#   away_manager_country_id  away_manager_country_name data_version  \
# 0                     154                    Morocco        1.1.0
# 1                     183                   Portugal        1.1.0
# 2                     214                      Spain        1.1.0
# 3                      11                  Argentina        1.1.0
# 4                     214                      Spain        1.1.0
#
#   shot_fidelity_version xy_fidelity_version
# 0                     2                   2
# 1                     2                   2
# 2                     2                   2
# 3                     2                   2
# 4                     2                   2
#
# [5 rows x 55 columns]

# %%
#Final Match ID: 3869685
match_ids_array = matches['match_id'].to_numpy()
print(match_ids_array)
# Out:
# [3857276 3857271 3857296 3857274 3857255 3857272 3857278 3857277 3857273
#  3857275 3857261 3857290 3857298 3857285 3857282 3857297 3857294 3857266
#  3857284 3857254 3857265 3857301 3857268 3857269 3869321 3857292 3857295
#  3869685 3869684 3857256 3869151 3857257 3857258 3857288 3857267 3857287
#  3869486 3857260 3857264 3857289 3869254 3869118 3869519 3869354 3869552
#  3869420 3869220 3869219 3869253 3869152 3869117 3857270 3857263 3857259
#  3857283 3857286 3857300 3857299 3857293 3857291 3857281 3857280 3857279
#  3857262]

# %%
events.shape
# Out:
# (3963, 92)
